# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\bhawna\\Downloads\\Shark Tank India Dataset.csv")

# %%
data.head(10)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
# 5               2             6         Agro tourism
# 6               3             7          Qzense Labs
# 7               3             8            Peeschute
# 8               3             9                 NOCD
# 9               4            10                Cosiq
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
# 2                             Detachable Sleeves     1                25.0
# 3                           Healthy Potato Chips     1                70.0
# ...

# %%
import numpy as np

# %%
data.iloc[np.where((data["ashneer_deal"]==1) & (data["amount_per_shark"]) & (data["equity_per_shark"]))][:]
# Out:
#      episode_number  pitch_number             brand_name  \
# 0                 1             1    BluePine Industries
# 1                 1             2          Booz scooters
# 3                 2             4             Tagz Foods
# 15                6            16            Skippi Pops
# 18                7            19     Raising Superstars
# 21                8            22           Beyond Snack
# 23                8            24          Motion Breeze
# 29               10            30              EventBeep
# 38               13            39        The Yarn Bazaar
# 45               16            46           Bamboo India
# 49               17            50  Find Your Kicks India
# 50               17            51          Aas Vidyalaya
# 55               18            56                   Otua
# 58               19            59                WeSTOCK
# 63               20            64               IN A CAN
# ...

# %% [markdown]
# # Ashneer invested in 21 different brands

# %%
data.groupby(["ashneer_deal"])["amount_per_shark"].sum()
# Out:
# ashneer_deal
# 0    1627.166936
# 1     494.333333
# Name: amount_per_shark, dtype: float64

# %% [markdown]
# # * Ashneer invested 4 Cr 94 lakhs in Total

# %%
data.groupby(["ashneer_deal"])["amount_per_shark"].max()
# Out:
# ashneer_deal
# 0    100.0
# 1     70.0
# Name: amount_per_shark, dtype: float64

# %%
data.groupby(["ashneer_deal"])["equity_per_shark"].max()
# Out:
# ashneer_deal
# 0    75.0
# 1    25.0
# Name: equity_per_shark, dtype: float64

# %%
data.iloc[np.where((data["ashneer_deal"]==1) & (data["equity_per_shark"]==25.0))]
# Out:
#    episode_number  pitch_number     brand_name  \
# 1               1             2  Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 1            0                      2              20.0              25.0
#
# [1 rows x 28 columns]

# %% [markdown]
# # Ashneer has maximum equity of 25% of Booz scooters with an amount of 20 lakhs invested

# %% [markdown]
# # Ashneer invested 70 lakhs as the maximum in comparison to all his investments  with 2.75 equity in Tagz Foods

# %%
f_data = pd.DataFrame(columns = (["Total no. of investments"],["max._Equity"],["max.Equity company name"],["Total_Investment"],["max. Investment"]),index = ("Ashneer Grover","Anupam","Aman","Namita","vineeta","peyush","ghazal"))

# %%
data.iloc[np.where(data["anupam_deal"]==1)].shape
# Out:
# (24, 28)

# %% [markdown]
# # ANUMPAM invested in 24 companies in total

# %%
data.groupby(["anupam_deal"])["amount_per_shark"].sum()
# Out:
# anupam_deal
# 0    1587.666667
# 1     533.833603
# Name: amount_per_shark, dtype: float64

# %% [markdown]
# # Anupam invested 5 Cr 33 lakhs Total

# %%
data.groupby(["anupam_deal"])["amount_per_shark"].max()
# Out:
# anupam_deal
# 0    100.0
# 1     50.0
# Name: amount_per_shark, dtype: float64

# %%
data.iloc[np.where((data["anupam_deal"]==1) & (data["amount_per_shark"]==50.0))]
# Out:
#     episode_number  pitch_number                brand_name           idea  \
# 12               5            13               Revamp Moto         E-Bike
# 31              11            32  ARRCOAT Surface Textures  Wall Building
# 78              25            79                 PawsIndia   Dog Products
#
#     deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 12     1               100.0         1.0        10000.0        100.0
# 31     1                50.0         5.0         1000.0         50.0
# 78     1                50.0         4.0         1250.0         50.0
#
#     deal_equity  ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  \
# 12          1.5  ...             0            1          1            0
# 31         15.0  ...             0            1          0            0
# 78         15.0  ...             0            1          0            0
#
#     vineeta_deal  peyush_deal  ghazal_deal  total_sharks_invested  \
# ...

# %%
data.groupby(["anupam_deal"])["equity_per_shark"].max()
# Out:
# anupam_deal
# 0    75.0
# 1    17.5
# Name: equity_per_shark, dtype: float64

# %%
data.iloc[np.where((data["anupam_deal"]==1) & (data["equity_per_shark"]==17.5))]
# Out:
#     episode_number  pitch_number    brand_name   idea  deal  \
# 75              24            76  The Sass Bar  Gifts     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 75                40.0         8.0          500.0         50.0         35.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 75  ...             0            1          0            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 75            0            1                      2              25.0
#
#     equity_per_shark
# 75              17.5
#
# [1 rows x 28 columns]

# %% [markdown]
# # anupam has max equity of 17.5 % of The sass Bar with an amount of 25 lakhs invested

# %% [markdown]
# # anupam's max amount invested was 50 lakhs in 3 different companies

# %%
data.iloc[np.where(data["aman_deal"]==1)].shape
# Out:
# (28, 28)

# %%
data.groupby(["aman_deal"])["amount_per_shark"].sum()
# Out:
# aman_deal
# 0    1234.000252
# 1     887.500017
# Name: amount_per_shark, dtype: float64

# %%
data.groupby(["aman_deal"])["equity_per_shark"].max()
# Out:
# aman_deal
# 0    75.0
# 1    40.0
# Name: equity_per_shark, dtype: float64

# %%
data.iloc[np.where((data["aman_deal"]==1) & (data["equity_per_shark"]==40.0))]
# Out:
#     episode_number  pitch_number        brand_name                  idea  \
# 42              15            43  Hammer Lifestyle  Smart Audio Products
#
#     deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 42     1                30.0         3.0         1000.0        100.0
#
#     deal_equity  ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  \
# 42         40.0  ...             0            0          1            0
#
#     vineeta_deal  peyush_deal  ghazal_deal  total_sharks_invested  \
# 42             0            0            0                      1
#
#     amount_per_shark  equity_per_shark
# 42             100.0              40.0
#
# [1 rows x 28 columns]

# %%
data.groupby(["aman_deal"])["amount_per_shark"].max()
# Out:
# aman_deal
# 0    100.0
# 1    100.0
# Name: amount_per_shark, dtype: float64

# %% [markdown]
# # Aman has invested in a total of 28 brands with a total amount of 8 Cr 87 lakhs as of now and he holds a max of 40%equity in the company Hammer Lifestyle with max investment of 1 Cr.

# %%
data.iloc[np.where(data["namita_deal"]==1)].shape
# Out:
# (22, 28)

# %%
data.groupby(["namita_deal"])["amount_per_shark"].sum()
# Out:
# namita_deal
# 0    1473.166667
# 1     648.333603
# Name: amount_per_shark, dtype: float64

# %%
data.groupby(["namita_deal"])["equity_per_shark"].max()
# Out:
# namita_deal
# 0    75.0
# 1    25.0
# Name: equity_per_shark, dtype: float64

# %%
data.iloc[np.where((data["namita_deal"]==1) & (data["equity_per_shark"]==25.0))]
# Out:
#      episode_number  pitch_number     brand_name     idea  deal  \
# 106              33           107  Colour Me Mad  Insoles     1
#
#      pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 106                40.0        10.0          400.0         40.0         25.0
#
#      ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 106  ...             0            0          0            1             0
#
#      peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 106            0            0                      1              40.0
#
#      equity_per_shark
# 106              25.0
#
# [1 rows x 28 columns]

# %%
data.groupby(["namita_deal"])["amount_per_shark"].max()
# Out:
# namita_deal
# 0    100.0
# 1     75.0
# Name: amount_per_shark, dtype: float64

# %%
data.iloc[np.where((data["namita_deal"]==1) & (data["amount_per_shark"]==75.0))]
# Out:
#     episode_number  pitch_number      brand_name                idea  deal  \
# 33              12            34  Auli Lifestyle  Ayurvedic Products     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 33                75.0         4.0         1875.0         75.0         15.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 33  ...             0            0          0            1             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 33            0            0                      1              75.0
#
#     equity_per_shark
# 33              15.0
#
# [1 rows x 28 columns]

# %% [markdown]
# # Namita has invested in a total of 22 Brands with a total amount of 6 Cr and 48 lakhs invested till now. She holds a max of 25% equity in the company Colour Me Bad and her max investment reached 75 Lakhs for a company called Auli lifestyle.

# %%
data.iloc[np.where(data["vineeta_deal"]==1)].shape
# Out:
# (15, 28)

# %%
data.groupby(["vineeta_deal"])["amount_per_shark"].sum()
# Out:
# vineeta_deal
# 0    1793.166936
# 1     328.333333
# Name: amount_per_shark, dtype: float64

# %%
data.groupby(["vineeta_deal"])["equity_per_shark"].max()
# Out:
# vineeta_deal
# 0    75.0
# 1    25.0
# Name: equity_per_shark, dtype: float64

# %%
data.iloc[np.where((data["vineeta_deal"]==1) & (data["equity_per_shark"]==25.0))]
# Out:
#    episode_number  pitch_number     brand_name  \
# 1               1             2  Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 1            0                      2              20.0              25.0
#
# [1 rows x 28 columns]

# %%
data.groupby(["vineeta_deal"])["amount_per_shark"].max()
# Out:
# vineeta_deal
# 0    100.0
# 1     40.0
# Name: amount_per_shark, dtype: float64

# %%
data.iloc[np.where((data["vineeta_deal"]==1) & (data["amount_per_shark"]==40.0))]
# Out:
#     episode_number  pitch_number    brand_name             idea  deal  \
# 95              30            96  Kabaddi Adda  All-Kabaddi App     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 95                80.0         1.0         8000.0         80.0          6.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 95  ...             0            0          0            1             1
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 95            0            0                      2              40.0
#
#     equity_per_shark
# 95               3.0
#
# [1 rows x 28 columns]

# %% [markdown]
# # Vineeta has invested in a total of 15 Brands with a total amount of 3 Cr and 28 lakhs invested till now. She holds a max of 25% equity in the company Booz Scooters and her max investment reached 40 Lakhs for a company called Kabaddi adda.

# %%
data.iloc[np.where(data["peyush_deal"]==1)].shape
# Out:
# (27, 28)

# %%
data.groupby(["peyush_deal"])["amount_per_shark"].sum()
# Out:
# peyush_deal
# 0    1401.833350
# 1     719.666919
# Name: amount_per_shark, dtype: float64

# %%
data.groupby(["peyush_deal"])["equity_per_shark"].max()
# Out:
# peyush_deal
# 0    40.0
# 1    75.0
# Name: equity_per_shark, dtype: float64

# %%
data.iloc[np.where((data["peyush_deal"]==1) & (data["equity_per_shark"]==75.0))]
# Out:
#     episode_number  pitch_number     brand_name        idea  deal  \
# 65              21            66  Sid07 Designs  Inventions     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 65                47.0        10.0          470.0         25.0         75.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 65  ...             0            0          0            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 65            1            0                      1              25.0
#
#     equity_per_shark
# 65              75.0
#
# [1 rows x 28 columns]

# %%
data.groupby(["peyush_deal"])["amount_per_shark"].max()
# Out:
# peyush_deal
# 0    100.0
# 1    100.0
# Name: amount_per_shark, dtype: float64

# %%
data.iloc[np.where((data["peyush_deal"]==1) & (data["amount_per_shark"]==100))]
# Out:
#     episode_number  pitch_number          brand_name                 idea  \
# 87              27            88  Insurance Samadhan  Insurance Solutions
#
#     deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 87     1               100.0         1.0        10000.0        100.0
#
#     deal_equity  ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  \
# 87          4.0  ...             0            0          0            0
#
#     vineeta_deal  peyush_deal  ghazal_deal  total_sharks_invested  \
# 87             0            1            0                      1
#
#     amount_per_shark  equity_per_shark
# 87             100.0               4.0
#
# [1 rows x 28 columns]

# %% [markdown]
# # Peyush has invested in a total of 27 Brands with a total amount of 7 Cr and 19 lakhs invested till now. He holds a max of 75% equity in the company Sid Designs and his max investment reached 1 Cr for a company called Insurance Samadhan.

# %%
data.iloc[np.where(data["ghazal_deal"]==1)].shape
# Out:
# (7, 28)

# %%
data.groupby(["ghazal_deal"])["amount_per_shark"].sum()
# Out:
# ghazal_deal
# 0    1991.500017
# 1     130.000253
# Name: amount_per_shark, dtype: float64

# %%
data.groupby(["ghazal_deal"])["equity_per_shark"].max()
# Out:
# ghazal_deal
# 0    75.0
# 1    17.5
# Name: equity_per_shark, dtype: float64

# %%
data.iloc[np.where((data["ghazal_deal"]==1) & (data["equity_per_shark"]==17.5))]
# Out:
#     episode_number  pitch_number    brand_name   idea  deal  \
# 75              24            76  The Sass Bar  Gifts     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 75                40.0         8.0          500.0         50.0         35.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 75  ...             0            1          0            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 75            0            1                      2              25.0
#
#     equity_per_shark
# 75              17.5
#
# [1 rows x 28 columns]

# %%
data.groupby(["ghazal_deal"])["amount_per_shark"].max()
# Out:
# ghazal_deal
# 0    100.000000
# 1     33.333333
# Name: amount_per_shark, dtype: float64

# %%
data.iloc[np.where((data["ghazal_deal"]==1))]
# Out:
#      episode_number  pitch_number                brand_name  \
# 75               24            76              The Sass Bar
# 79               25            80       Sunfox Technologies
# 85               27            86        Watt Technovations
# 88               28            89                  Humpy A2
# 90               28            91  Gold Safe Solutions Ind.
# 91               29            92               Wakao Foods
# 110              34           111        Nomad Food Project
#
#                       idea  deal  pitcher_ask_amount  ask_equity  \
# 75                   Gifts     1            40.00000         8.0
# 79     Portable ECG Device     1           100.00000         2.0
# 85     Ventilated PPE Kits     1             0.00101        10.0
# 88   Organic Milk Products     1            75.00000         4.0
# 90   Anti-Suicidal Fan Rod     1            50.00000         5.0
# 91      Jackfruit Products     1            75.00000         5.0
# ...

# %% [markdown]
# # Ghazal has invested in a total of 7 Brands with a total amount of 1 Cr and 30 lakhs invested till now. He holds a max of 17.5% equity in the company The Sass Bar and his max investment reached 33.3 lakhs for a company called Humpy A2.

# %%
f_data
# Out:
#                (Total no. of investments,) (max._Equity,)  \
# Ashneer Grover                         NaN            NaN
# Anupam                                 NaN            NaN
# Aman                                   NaN            NaN
# Namita                                 NaN            NaN
# vineeta                                NaN            NaN
# peyush                                 NaN            NaN
# ghazal                                 NaN            NaN
#
#                (max.Equity company name,) (Total_Investment,)  \
# Ashneer Grover                        NaN                 NaN
# Anupam                                NaN                 NaN
# Aman                                  NaN                 NaN
# Namita                                NaN                 NaN
# vineeta                               NaN                 NaN
# peyush                                NaN                 NaN
# ghazal                                NaN                 NaN
# ...

# %%
f_data["Total_no. of investments"] = [21,24,28,22,15,27,7]

# %%
f_data["max_equity"] = ["25%","17.5%","40%","25%","25%","75%","17.5%"]

# %%
f_data["max_quity_company_name"] = ["Booz Scooters","PAWS INDIA","Hammer Lifestyle","Colour Me Bad","Booz Scooters","Sid Designs","The Sass Bar"]

# %%
f_data["Total_investment(in lakhs)"] = [494,533,887,648,328,719,130]

# %%
f_data["Max_Investment (in lakhs)"] = [70,50,100,75,40,100,33.3]

# %%
F_data = f_data.iloc[:,5:]

# %%
F_data
# Out:
#                 Total_no. of investments max_equity max_quity_company_name  \
# Ashneer Grover                        21        25%          Booz Scooters
# Anupam                                24      17.5%             PAWS INDIA
# Aman                                  28        40%       Hammer Lifestyle
# Namita                                22        25%          Colour Me Bad
# vineeta                               15        25%          Booz Scooters
# peyush                                27        75%            Sid Designs
# ghazal                                 7      17.5%           The Sass Bar
#
#                 Total_investment(in lakhs)  Max_Investment (in lakhs)
# Ashneer Grover                         494                       70.0
# Anupam                                 533                       50.0
# Aman                                   887                      100.0
# Namita                                 648                       75.0
# ...

# %% [markdown]
# # THE DATA ABOVE DEPICTS THE IMPORTANT INFORMATION WHICH COULD BE GATHERED FROM THE WHOLE DATA SET.

# %%
data["total_sharks_invested"].max()
# Out:
# 5

# %%
data.iloc[np.where((data["total_sharks_invested"]==5))]
# Out:
#     episode_number  pitch_number             brand_name                 idea  \
# 15               6            16            Skippi Pops             Ice-Pops
# 49              17            50  Find Your Kicks India       Sneaker Resale
# 63              20            64               IN A CAN        Can Cocktails
# 79              25            80    Sunfox Technologies  Portable ECG Device
#
#     deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 15     1                45.0         5.0          900.0        100.0
# 49     1                50.0        10.0          500.0         50.0
# 63     1                50.0         2.0         2500.0        100.0
# 79     1               100.0         2.0         5000.0        100.0
#
#     deal_equity  ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  \
# 15         15.0  ...             1            1          1            1
# 49         25.0  ...             1            1          1            1
# ...

# %% [markdown]
# # THE BRANDS WHICH PULLED THE MAXIMUM NUMBER OF SHARKS WERE THE ABOVE 4.

# %%
data["total_sharks_invested"].min()
# Out:
# 0

# %%
data.iloc[np.where((data["total_sharks_invested"]==0))]
# Out:
#      episode_number  pitch_number                 brand_name  \
# 4                 2             5             Head and Heart
# 5                 2             6               Agro tourism
# 6                 3             7                Qzense Labs
# 10                4            11               JhaJi Achaar
# 13                5            14               Hungry Heads
# 14                5            15         Shrawani Engineers
# 17                6            18                    Hecolll
# 19                7            20                   Torch-it
# 20                7            21              La Kheer Deli
# 26                9            27            Kabira Handmade
# 30               11            31                 Gopal's 56
# 34               12            35                   SweeDesi
# 40               14            41         Morikko Pure Foods
# 41               14            42       Good Good Piggy Bank
# ...

# %% [markdown]
# # From the above data it is clear that 52 brands were such that nobody liked investing in them.
