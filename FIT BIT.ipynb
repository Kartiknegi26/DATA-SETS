# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
daily_cal = pd.read_csv("dailyCalories_merged.csv")

# %%
daily_cal
# Out:
#              Id ActivityDay  Calories
# 0    1503960366   4/12/2016      1985
# 1    1503960366   4/13/2016      1797
# 2    1503960366   4/14/2016      1776
# 3    1503960366   4/15/2016      1745
# 4    1503960366   4/16/2016      1863
# ..          ...         ...       ...
# 935  8877689391    5/8/2016      2847
# 936  8877689391    5/9/2016      3710
# 937  8877689391   5/10/2016      2832
# 938  8877689391   5/11/2016      3832
# 939  8877689391   5/12/2016      1849
#
# [940 rows x 3 columns]

# %%
daily_cal = daily_cal[daily_cal["Id"]==6962181067]dd
# Out:
#   File "C:\Users\bhawna\AppData\Local\Temp/ipykernel_19516/1338688248.py", line 1
#     daily_cal = daily_cal[daily_cal["Id"]==6962181067]dd
#                                                       ^
# SyntaxError: invalid syntax

# %%
min_c = pd.read_csv("minuteCaloriesNarrow_merged.csv")

# %%
min_c[min_c["Id"]==6962181067]
# Out:
#                  Id         ActivityMinute  Calories
# 960240   6962181067  4/12/2016 12:00:00 AM   0.90400
# 960241   6962181067  4/12/2016 12:01:00 AM   0.90400
# 960242   6962181067  4/12/2016 12:02:00 AM   0.99440
# 960243   6962181067  4/12/2016 12:03:00 AM   0.90400
# 960244   6962181067  4/12/2016 12:04:00 AM   0.90400
# ...             ...                    ...       ...
# 1004155  6962181067  5/12/2016 11:55:00 AM   1.08024
# 1004156  6962181067  5/12/2016 11:56:00 AM   1.08024
# 1004157  6962181067  5/12/2016 11:57:00 AM   1.08024
# 1004158  6962181067  5/12/2016 11:58:00 AM   1.08024
# 1004159  6962181067  5/12/2016 11:59:00 AM   0.99022
#
# [43920 rows x 3 columns]

# %%
heart_rate = pd.read_csv("heartrate_seconds_merged.csv")

# %%
heart_rate_1 = heart_rate[heart_rate["Id"]==6962181067]

# %% [markdown]
# # fetched out heart rate record for a specidfic customer Id

# %%
heart_rate_1
# Out:
#                  Id                   Time  Value
# 1732058  6962181067  4/12/2016 12:00:10 AM     71
# 1732059  6962181067  4/12/2016 12:00:20 AM     72
# 1732060  6962181067  4/12/2016 12:00:30 AM     72
# 1732061  6962181067  4/12/2016 12:00:45 AM     72
# 1732062  6962181067  4/12/2016 12:01:00 AM     71
# ...             ...                    ...    ...
# 1998379  6962181067  5/12/2016 11:55:50 AM     91
# 1998380  6962181067  5/12/2016 11:56:00 AM     90
# 1998381  6962181067  5/12/2016 11:56:10 AM     97
# 1998382  6962181067  5/12/2016 11:56:15 AM     97
# 1998383  6962181067  5/12/2016 11:56:30 AM     95
#
# [266326 rows x 3 columns]

# %%
time_1 = heart_rate_1["Time"].str.split(" ",expand = True) 
time_1
# Out:
#                  0         1   2
# 1732058  4/12/2016  12:00:10  AM
# 1732059  4/12/2016  12:00:20  AM
# 1732060  4/12/2016  12:00:30  AM
# 1732061  4/12/2016  12:00:45  AM
# 1732062  4/12/2016  12:01:00  AM
# ...            ...       ...  ..
# 1998379  5/12/2016  11:55:50  AM
# 1998380  5/12/2016  11:56:00  AM
# 1998381  5/12/2016  11:56:10  AM
# 1998382  5/12/2016  11:56:15  AM
# 1998383  5/12/2016  11:56:30  AM
#
# [266326 rows x 3 columns]

# %% [markdown]
# # SPLITTED the columns to filter even further and named it time_1

# %%
time_1.rename(columns = {0: "Date",1: "Time1",2:"AM/PM"},inplace = True)

# %%
time_1
# Out:
#               Date     Time1 AM/PM
# 1732058  4/12/2016  12:00:10    AM
# 1732059  4/12/2016  12:00:20    AM
# 1732060  4/12/2016  12:00:30    AM
# 1732061  4/12/2016  12:00:45    AM
# 1732062  4/12/2016  12:01:00    AM
# ...            ...       ...   ...
# 1998379  5/12/2016  11:55:50    AM
# 1998380  5/12/2016  11:56:00    AM
# 1998381  5/12/2016  11:56:10    AM
# 1998382  5/12/2016  11:56:15    AM
# 1998383  5/12/2016  11:56:30    AM
#
# [266326 rows x 3 columns]

# %%
heart_rate_1.reset_index(inplace = True)

# %% [markdown]
# # reset the index to obtain a column named 'index'

# %%
heart_rate_1
# Out:
#           index          Id                   Time  Value
# 0       1732058  6962181067  4/12/2016 12:00:10 AM     71
# 1       1732059  6962181067  4/12/2016 12:00:20 AM     72
# 2       1732060  6962181067  4/12/2016 12:00:30 AM     72
# 3       1732061  6962181067  4/12/2016 12:00:45 AM     72
# 4       1732062  6962181067  4/12/2016 12:01:00 AM     71
# ...         ...         ...                    ...    ...
# 266321  1998379  6962181067  5/12/2016 11:55:50 AM     91
# 266322  1998380  6962181067  5/12/2016 11:56:00 AM     90
# 266323  1998381  6962181067  5/12/2016 11:56:10 AM     97
# 266324  1998382  6962181067  5/12/2016 11:56:15 AM     97
# 266325  1998383  6962181067  5/12/2016 11:56:30 AM     95
#
# [266326 rows x 4 columns]

# %%
time_1.reset_index(inplace = True)

# %%
heart_rate_1.drop(columns = "Time",inplace = True)
# Out:
# C:\Users\bhawna\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
heart_rate_1.head(2)
# Out:
#      index          Id  Value
# 0  1732058  6962181067     71
# 1  1732059  6962181067     72

# %%
time_1.head(2)
# Out:
#      index       Date     Time1 AM/PM
# 0  1732058  4/12/2016  12:00:10    AM
# 1  1732059  4/12/2016  12:00:20    AM

# %%
data_heart = pd.merge(heart_rate_1,time_1,how = "inner",on = "index")

# %% [markdown]
# # merged the two heart rate and time1 datas on the basis of their index

# %%
data_heart
# Out:
#           index          Id  Value       Date     Time1 AM/PM
# 0       1732058  6962181067     71  4/12/2016  12:00:10    AM
# 1       1732059  6962181067     72  4/12/2016  12:00:20    AM
# 2       1732060  6962181067     72  4/12/2016  12:00:30    AM
# 3       1732061  6962181067     72  4/12/2016  12:00:45    AM
# 4       1732062  6962181067     71  4/12/2016  12:01:00    AM
# ...         ...         ...    ...        ...       ...   ...
# 266321  1998379  6962181067     91  5/12/2016  11:55:50    AM
# 266322  1998380  6962181067     90  5/12/2016  11:56:00    AM
# 266323  1998381  6962181067     97  5/12/2016  11:56:10    AM
# 266324  1998382  6962181067     97  5/12/2016  11:56:15    AM
# 266325  1998383  6962181067     95  5/12/2016  11:56:30    AM
#
# [266326 rows x 6 columns]

# %%
df_heart = data_heart.iloc[np.where((data_heart["Time1"]=="12:00:10") & (data_heart["AM/PM"]=="AM"))]

# %%
df_heart=df_heart[["index","Id","Date","Time1","AM/PM","Value"]]

# %%
df_heart.head(30)
# Out:
#           index          Id       Date     Time1 AM/PM  Value
# 0       1732058  6962181067  4/12/2016  12:00:10    AM     71
# 9197    1741255  6962181067  4/13/2016  12:00:10    AM     84
# 17463   1749521  6962181067  4/14/2016  12:00:10    AM     71
# 25552   1757610  6962181067  4/15/2016  12:00:10    AM     64
# 33906   1765964  6962181067  4/16/2016  12:00:10    AM     71
# 43786   1775844  6962181067  4/17/2016  12:00:10    AM     64
# 52052   1784110  6962181067  4/18/2016  12:00:10    AM     66
# 60014   1792072  6962181067  4/19/2016  12:00:10    AM     59
# 77511   1809569  6962181067  4/21/2016  12:00:10    AM     65
# 86657   1818715  6962181067  4/22/2016  12:00:10    AM     61
# 95723   1827781  6962181067  4/23/2016  12:00:10    AM     63
# 105579  1837637  6962181067  4/24/2016  12:00:10    AM     59
# 114222  1846280  6962181067  4/25/2016  12:00:10    AM     61
# 132232  1864290  6962181067  4/27/2016  12:00:10    AM     68
# ...

# %%
plt.plot(df_heart["Date"],df_heart["Value"])
plt.xticks(df_heart["Date"][0:-1:4])
# Out:
# ([<matplotlib.axis.XTick at 0x1b0640ff820>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # reordered the columns for better undertstanding,
# ## named it df_heart

# %%
df_heart.head()
# Out:
#          index          Id       Date     Time1 AM/PM  Value
# 0      1732058  6962181067  4/12/2016  12:00:10    AM     71
# 9197   1741255  6962181067  4/13/2016  12:00:10    AM     84
# 17463  1749521  6962181067  4/14/2016  12:00:10    AM     71
# 25552  1757610  6962181067  4/15/2016  12:00:10    AM     64
# 33906  1765964  6962181067  4/16/2016  12:00:10    AM     71

# %%
df_heart.shape
# Out:
# (23, 6)

# %% [markdown]
# # now we need to fetch more important insights from other datatsets

# %%
daily_cal.head(5)
# Out:
#            Id ActivityDay  Calories
# 0  1503960366   4/12/2016      1985
# 1  1503960366   4/13/2016      1797
# 2  1503960366   4/14/2016      1776
# 3  1503960366   4/15/2016      1745
# 4  1503960366   4/16/2016      1863

# %%
daily_cal.drop(columns = "Id",inplace = True)

# %%
daily_cal.shape
# Out:
# (940, 2)

# %%
daily_cal.rename(columns = {"ActivityDay":"Date"},inplace = True)

# %%
daily_cal.head(5)
# Out:
#         Date  Calories
# 0  4/12/2016      1985
# 1  4/13/2016      1797
# 2  4/14/2016      1776
# 3  4/15/2016      1745
# 4  4/16/2016      1863

# %% [markdown]
# # Merged heart rate and daily calories data

# %%
df = pd.merge(df_heart,daily_cal,how = "inner",on = "Date")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19516/2250731012.py in <module>
# ----> 1 df = pd.merge(df_heart,daily_cal,how = "inner",on = "Date")
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
# ...

# %%
df.head()

# %%
plt.figure(figsize = (15,8))
plt.subplot(1,2,1)
plt.plot(df["Date"],df["Value"])
plt.xticks(df["Date"][0:-1:4])

plt.subplot(1,2,2)
plt.plot(df["Date"],df["Calories"])
plt.xticks(df_heart["Date"][0:-1:4])
# Out:
# ([<matplotlib.axis.XTick at 0x1f03e2b0c40>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # INSIGHTS DRAWN:
# # 1. IT CAN BE CLEARLY SEEN THAT CALORIES BURNT AND HEART RATE ARE INVERSELY PROPORTIONAL TO EACH OTHER WHICH MEANS THAT THE MORE YOU BURN YOUR CALORIES WITH PHYSICAL ACTIVITIES THE HEALTHIER YOUR HEART WILL BE.
# # 2. BETTER CHOLESTROL LEVELS

# %%
df.shape
# Out:
# (23, 7)

# %%
df.head()
# Out:
#      index          Id       Date     Time1 AM/PM  Value  Calories
# 0  1732058  6962181067  4/12/2016  12:00:10    AM     71      1994
# 1  1741255  6962181067  4/13/2016  12:00:10    AM     84      1718
# 2  1749521  6962181067  4/14/2016  12:00:10    AM     71      1466
# 3  1757610  6962181067  4/15/2016  12:00:10    AM     64      1756
# 4  1765964  6962181067  4/16/2016  12:00:10    AM     71      2173

# %%
weight_log = pd.read_csv("weightLogInfo_merged.csv")

# %%
weight_log
# Out:
#             Id                   Date    WeightKg  WeightPounds   Fat  \
# 0   1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1   1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2   1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3   2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4   2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
# ..         ...                    ...         ...           ...   ...
# 62  8877689391    5/6/2016 6:43:35 AM   85.000000    187.392923   NaN
# 63  8877689391    5/8/2016 7:35:53 AM   85.400002    188.274775   NaN
# 64  8877689391    5/9/2016 6:39:44 AM   85.500000    188.495234   NaN
# 65  8877689391   5/11/2016 6:51:47 AM   85.400002    188.274775   NaN
# 66  8877689391   5/12/2016 6:42:53 AM   84.000000    185.188300   NaN
#
#           BMI  IsManualReport          LogId
# 0   22.650000            True  1462233599000
# ...

# %%
weight_log = weight_log[weight_log["Id"]==6962181067]

# %%
weight_log_1 = weight_log["Date"].str.split(" ",expand = True)

# %%
weight_log_1
# Out:
#             0         1   2
# 13  4/12/2016  11:59:59  PM
# 14  4/13/2016  11:59:59  PM
# 15  4/14/2016  11:59:59  PM
# 16  4/15/2016  11:59:59  PM
# 17  4/16/2016  11:59:59  PM
# 18  4/17/2016  11:59:59  PM
# 19  4/18/2016  11:59:59  PM
# 20  4/19/2016  11:59:59  PM
# 21  4/20/2016  11:59:59  PM
# 22  4/21/2016  11:59:59  PM
# 23  4/22/2016  11:59:59  PM
# 24  4/23/2016  11:59:59  PM
# 25  4/24/2016  11:59:59  PM
# 26  4/25/2016  11:59:59  PM
# 27  4/27/2016  11:59:59  PM
# 28  4/28/2016  11:59:59  PM
# 29  4/29/2016  11:59:59  PM
# 30  4/30/2016  11:59:59  PM
# 31   5/1/2016  11:59:59  PM
# 32   5/2/2016  11:59:59  PM
# 33   5/3/2016  11:59:59  PM
# 34   5/4/2016  11:59:59  PM
# 35   5/5/2016  11:59:59  PM
# 36   5/6/2016  11:59:59  PM
# 37   5/7/2016  11:59:59  PM
# 38   5/8/2016  11:59:59  PM
# 39   5/9/2016  11:59:59  PM
# 40  5/10/2016  11:59:59  PM
# 41  5/11/2016  11:59:59  PM
# 42  5/12/2016  11:59:59  PM

# %%
weight_log["DATE"] = weight_log_1[0]
# Out:
# C:\Users\bhawna\AppData\Local\Temp/ipykernel_10268/1872150684.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weight_log["DATE"] = weight_log_1[0]

# %%
weight_log.head()
# Out:
#             Id                   Date   WeightKg  WeightPounds  Fat  \
# 13  6962181067  4/12/2016 11:59:59 PM  62.500000    137.788914  NaN
# 14  6962181067  4/13/2016 11:59:59 PM  62.099998    136.907061  NaN
# 15  6962181067  4/14/2016 11:59:59 PM  61.700001    136.025217  NaN
# 16  6962181067  4/15/2016 11:59:59 PM  61.500000    135.584291  NaN
# 17  6962181067  4/16/2016 11:59:59 PM  62.000000    136.686603  NaN
#
#           BMI  IsManualReport          LogId       DATE
# 13  24.389999            True  1460505599000  4/12/2016
# 14  24.240000            True  1460591999000  4/13/2016
# 15  24.100000            True  1460678399000  4/14/2016
# 16  24.000000            True  1460764799000  4/15/2016
# 17  24.209999            True  1460851199000  4/16/2016

# %%
weight_log.drop(columns = "Date",inplace = True)
# Out:
# C:\Users\bhawna\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
weight_log.head(2)
# Out:
#             Id   WeightKg  WeightPounds  Fat        BMI  IsManualReport  \
# 13  6962181067  62.500000    137.788914  NaN  24.389999            True
# 14  6962181067  62.099998    136.907061  NaN  24.240000            True
#
#             LogId       DATE
# 13  1460505599000  4/12/2016
# 14  1460591999000  4/13/2016

# %%
weight_log.rename(columns = {"DATE":"Date"},inplace = True)
# Out:
# C:\Users\bhawna\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# # 1. Weight log merged with df1

# %%
df1 = pd.merge(df,weight_log,how = "inner",on = "Date")

# %%
df1.head(10)
# Out:
#      index        Id_x       Date     Time1 AM/PM  Value  Calories  \
# 0  1732058  6962181067  4/12/2016  12:00:10    AM     71      1994
# 1  1741255  6962181067  4/13/2016  12:00:10    AM     84      1718
# 2  1749521  6962181067  4/14/2016  12:00:10    AM     71      1466
# 3  1757610  6962181067  4/15/2016  12:00:10    AM     64      1756
# 4  1765964  6962181067  4/16/2016  12:00:10    AM     71      2173
# 5  1775844  6962181067  4/17/2016  12:00:10    AM     64      2027
# 6  1784110  6962181067  4/18/2016  12:00:10    AM     66      2039
# 7  1792072  6962181067  4/19/2016  12:00:10    AM     59      2046
# 8  1809569  6962181067  4/21/2016  12:00:10    AM     65      2179
# 9  1818715  6962181067  4/22/2016  12:00:10    AM     61      2086
#
#          Id_y   WeightKg  WeightPounds  Fat        BMI  IsManualReport  \
# 0  6962181067  62.500000    137.788914  NaN  24.389999            True
# 1  6962181067  62.099998    136.907061  NaN  24.240000            True
# ...

# %% [markdown]
# # RELATION BETWEEN BODY WEIGHT AND CALORIES BURNT

# %%
plt.figure(figsize = (15,8))


plt.subplot(1,2,1)
plt.plot(df1["Date"],df1["WeightKg"])
plt.xticks(df1["Date"][0:-1:4])
plt.ylabel("Weights(Kg)")


plt.subplot(1,2,2)
plt.plot(df1["Date"],df1["Calories"],"g")
plt.xticks(df1["Date"][0:-1:4])
plt.ylabel("Calories(kcal)")
# Out:
# Text(0, 0.5, 'Calories(kcal)')

# %% [markdown]
# # IT CAN BE CLEARLY SEEN THAT BURNING CALRIES HAS RESULTED IN A WEIGHT LOSS NOT A SIGNIFICANT DROP IN THE WEIGHT BUT THERE IS A BIT LOSS OF WEIGHT AND IN FACT BURNING CALORIES IS NOT THE ONLY FACTOR FOR WEIGHT LOSS. FACTORS LIKE CALORIC DEFICIT ALSO PLAYS A GOOD ROLE IN WEiGHT LOSS

# %%
df1.shape
# Out:
# (23, 14)

# %%
daily_activity = pd.read_csv("dailyActivity_merged.csv")

# %%
daily_activity = daily_activity[daily_activity["Id"]==6962181067]

# %%
daily_activity.head()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 680  6962181067    4/12/2016       10199           6.74             6.74
# 681  6962181067    4/13/2016        5652           3.74             3.74
# 682  6962181067    4/14/2016        1551           1.03             1.03
# 683  6962181067    4/15/2016        5563           3.68             3.68
# 684  6962181067    4/16/2016       13217           8.74             8.74
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 680                       0.0                3.40                      0.83
# 681                       0.0                0.57                      1.21
# 682                       0.0                0.00                      0.00
# 683                       0.0                0.00                      0.00
# 684                       0.0                3.66                      0.19
#
# ...

# %%
daily_activity.rename(columns = {"ActivityDate":"Date"},inplace = True)

# %%
daily_activity.drop(columns = "Id",inplace = True)

# %%
daily_activity.head()
# Out:
#           Date  TotalSteps  TotalDistance  TrackerDistance  \
# 680  4/12/2016       10199           6.74             6.74
# 681  4/13/2016        5652           3.74             3.74
# 682  4/14/2016        1551           1.03             1.03
# 683  4/15/2016        5563           3.68             3.68
# 684  4/16/2016       13217           8.74             8.74
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 680                       0.0                3.40                      0.83
# 681                       0.0                0.57                      1.21
# 682                       0.0                0.00                      0.00
# 683                       0.0                0.00                      0.00
# 684                       0.0                3.66                      0.19
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 680                 2.51                      0.0                 50
# ...

# %%
df1.rename(columns = {"Id_x":"Id"},inplace = True)

# %%
df1.drop(columns = "Id_y",inplace = True)

# %%
df1.head()
# Out:
#      index          Id       Date     Time1 AM/PM  Value  Calories   WeightKg  \
# 0  1732058  6962181067  4/12/2016  12:00:10    AM     71      1994  62.500000
# 1  1741255  6962181067  4/13/2016  12:00:10    AM     84      1718  62.099998
# 2  1749521  6962181067  4/14/2016  12:00:10    AM     71      1466  61.700001
# 3  1757610  6962181067  4/15/2016  12:00:10    AM     64      1756  61.500000
# 4  1765964  6962181067  4/16/2016  12:00:10    AM     71      2173  62.000000
#
#    WeightPounds  Fat        BMI  IsManualReport          LogId
# 0    137.788914  NaN  24.389999            True  1460505599000
# 1    136.907061  NaN  24.240000            True  1460591999000
# 2    136.025217  NaN  24.100000            True  1460678399000
# 3    135.584291  NaN  24.000000            True  1460764799000
# 4    136.686603  NaN  24.209999            True  1460851199000

# %%
df = pd.merge(df1,daily_activity,how = "inner",on = "Date")

# %%
df.head()
# Out:
#      index          Id       Date     Time1 AM/PM  Value  Calories_x  \
# 0  1732058  6962181067  4/12/2016  12:00:10    AM     71        1994
# 1  1741255  6962181067  4/13/2016  12:00:10    AM     84        1718
# 2  1749521  6962181067  4/14/2016  12:00:10    AM     71        1466
# 3  1757610  6962181067  4/15/2016  12:00:10    AM     64        1756
# 4  1765964  6962181067  4/16/2016  12:00:10    AM     71        2173
#
#     WeightKg  WeightPounds  Fat  ...  LoggedActivitiesDistance  \
# 0  62.500000    137.788914  NaN  ...                       0.0
# 1  62.099998    136.907061  NaN  ...                       0.0
# 2  61.700001    136.025217  NaN  ...                       0.0
# 3  61.500000    135.584291  NaN  ...                       0.0
# 4  62.000000    136.686603  NaN  ...                       0.0
#
#    VeryActiveDistance  ModeratelyActiveDistance  LightActiveDistance  \
# 0                3.40                      0.83                 2.51
# ...

# %%
sleep_day = pd.read_csv("sleepday_merged.csv")

# %%
sleep_day.head()
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
sleep_day_1 = sleep_day[sleep_day["Id"]==6962181067]

# %%
sleep_day_1.head()
# Out:
#              Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 306  6962181067  4/12/2016 12:00:00 AM                  1                 366
# 307  6962181067  4/13/2016 12:00:00 AM                  3                 630
# 308  6962181067  4/14/2016 12:00:00 AM                  2                 508
# 309  6962181067  4/15/2016 12:00:00 AM                  1                 370
# 310  6962181067  4/16/2016 12:00:00 AM                  1                 357
#
#      TotalTimeInBed
# 306             387
# 307             679
# 308             535
# 309             386
# 310             366

# %%
sleep_day_1.drop(columns = "Date",inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10268/348517788.py in <module>
# ----> 1 sleep_day_1.drop(columns = "Date",inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df1 = pd.merge()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19516/1370701969.py in <module>
# ----> 1 df1 = pd.merge()
#
# TypeError: merge() missing 2 required positional arguments: 'left' and 'right'

# %%
df.head()
# Out:
#      index          Id       Date     Time1 AM/PM  Value  Calories
# 0  1732058  6962181067  4/12/2016  12:00:10    AM     71      1985
# 1  1732058  6962181067  4/12/2016  12:00:10    AM     71      1432
# 2  1732058  6962181067  4/12/2016  12:00:10    AM     71      3199
# 3  1732058  6962181067  4/12/2016  12:00:10    AM     71      2030
# 4  1732058  6962181067  4/12/2016  12:00:10    AM     71      2220

# %%
df.describe()
# Out:
#               index            Id       Value     Calories
# count  7.000000e+02  7.000000e+02  700.000000   700.000000
# mean   1.845077e+06  6.962181e+09   66.404286  2297.434286
# std    8.008893e+04  0.000000e+00    5.618611   728.557775
# min    1.732058e+06  6.962181e+09   59.000000     0.000000
# 25%    1.775844e+06  6.962181e+09   63.000000  1819.000000
# 50%    1.827781e+06  6.962181e+09   65.000000  2114.000000
# 75%    1.925781e+06  6.962181e+09   71.000000  2761.500000
# max    1.994262e+06  6.962181e+09   84.000000  4900.000000

# %% [markdown]
# # 1. The above data shows that the person has an average heart rate of 66.39 which is considered healthy.
# # 2. The person's

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["Calories_x"],df["WeightKg"],"k*")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Calories_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
plt.bar(df["Calories_x"],df["BMI"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Calories_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df[""]
